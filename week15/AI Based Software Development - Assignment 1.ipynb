# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week15/AI%20Based%20Software%20Development%20-%20Assignment%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks = []

def add_task():
    name = input("Enter task name: ")
    priority = input("Enter priority (1=High, 2=Medium, 3=Low): ")

    if priority not in ["1", "2", "3"]:
        print("Invalid priority.\n")
        return

    tasks.append({"name": name, "priority": int(priority)})
    print("Task added!\n")

def view_tasks():
    if not tasks:
        print("No tasks available.\n")
        return

    print("\nYour Tasks:")
    for i, task in enumerate(tasks):
        print(f"{i+1}. {task['name']} (Priority {task['priority']})")
    print()

def main():
    while True:
        print("1. Add Task")
        print("2. View Tasks")
        print("3. Exit")

        choice = input("Choose an option: ")

        if choice == "1":
            add_task()
        elif choice == "2":
            view_tasks()
        elif choice == "3":
            print("Goodbye!")
            break
        else:
            print("Invalid choice.\n")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Choose an option: 1
# Enter task name: homework
# Enter priority (1=High, 2=Medium, 3=Low): 2
# Task added!
#
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Choose an option: 2
#
# Your Tasks:
# 1. homework (Priority 2)
#
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Choose an option: 3
# Goodbye!
