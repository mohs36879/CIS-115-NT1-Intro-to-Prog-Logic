# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week15/AI%20Based%20Software%20Development%20-%20Assignment%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os
from collections import defaultdict

# Constants
DATA_FILE = "game_data.json"

def load_data():
    """Load data from the JSON file. If file doesn't exist, return an empty dict."""
    if os.path.exists(DATA_FILE):
        with open(DATA_FILE, "r") as file:
            return json.load(file)
    return {}

def save_data(data):
    """Save the current session data to a JSON file."""
    with open(DATA_FILE, "w") as file:
        json.dump(data, file, indent=4)
    print("\n[System] Progress saved successfully.")

def main():
    # Load existing data
    game_sessions = load_data()

    while True:
        print("\n--- Game Session Tracker ---")
        print("1. Log a Game Session")
        print("2. View Stats (Total Hours & Most Played)")
        print("3. Save and Exit")

        choice = input("Select an option: ")

        if choice == "1":
            game_name = input("Enter the game name: ").strip()
            try:
                hours = float(input(f"How many hours did you play {game_name}? "))

                # Add hours to existing game or create new entry
                if game_name in game_sessions:
                    game_sessions[game_name] += hours
                else:
                    game_sessions[game_name] = hours
                print(f"Logged {hours} hours for {game_name}.")
            except ValueError:
                print("Error: Please enter a valid number for hours.")

        elif choice == "2":
            if not game_sessions:
                print("No data available yet.")
                continue

            print("\n--- Your Stats ---")
            most_played = None
            max_hours = 0

            for game, total in game_sessions.items():
                print(f"- {game}: {total} hours")
                if total > max_hours:
                    max_hours = total
                    most_played = game

            print(f"\nTotal Games Tracked: {len(game_sessions)}")
            print(f"Most Played Game: {most_played} ({max_hours} hours)")

        elif choice == "3":
            save_data(game_sessions)
            print("Goodbye!")
            break
        else:
            print("Invalid choice, try again.")

if __name__ == "__main__":
    main()
# Out:
# --- Game Session Tracker ---
# 1. Log a Game Session
# 2. View Stats (Total Hours & Most Played)
# 3. Save and Exit
