# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week10/Week%2010%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: roster.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# add_players function
def add_players(roster):
  # - accept a list as a parameter
  # - start a while loop that keeps running until user types "quit"
  while True:
    # - ask the user to enter a player name
    name = input("Enter player name (or 'quit' to stop): ")
    # - if user enters "quit", stop the loop
    if name == "quit":
      break
    # - otherwise, add the name to the list using append
    roster.append(name)

# is_on_roster function
def is_on_roster(roster, search_name):
  # - accept the list and a name to search

  # - loop through the list
  for player in roster:
    # - if name is found, return True
    if player == search_name:
      return True
  # - if loop ends without finding name, return False
  return False

# PROGRAM LOGIC
# - create empty list called roster
roster = []
# - call add_players to fill the list
add_players(roster)
# - ask user for one name to search for
search_name = input("Who would you like to search for? ")
# - call is_on_roster with roster and search name
result = is_on_roster(roster, search_name)
# - if True, print "Player found!"
if result == True:
  print("Result: Player found!")
# - if False, print "Player not found."
else:
  print("Result: Player not found.")
# - print roster to test that names were added
print(roster)
# Out:
# Enter player name (or 'quit' to stop): jj
# Enter player name (or 'quit' to stop): quit
# Who would you like to search for? i
# Result: Player not found.
# ['jj']
