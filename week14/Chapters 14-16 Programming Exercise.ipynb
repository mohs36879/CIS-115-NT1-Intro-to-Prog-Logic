# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week14/Chapters%2014-16%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: library.py
# IMPORT STATEMENTS

# CLASS DEFINITIONS

class Book:
  # __init__ method
  def __init__(self, title, author):
    # takes title and author as parameters
     # set self.title = title
     self.title = title
     # set self.author = author
     self.author = author
     # set self.is_available = True by default
     self.is_available = True


  # __str__ method
  def __str__(self):
    # if book is available -> show "Available"
   if self.is_available:
    status = "Available"
   else:
    status = "Checked Out"
   # otherwise -> show "Checked Out"
   # return formatted string with title, author, and status
   return self.title + " by " + self.author + " - " + status

  def checkout(self):
   # set book as checked out
   # set self.is_available to False
   self.is_available = False

  # return_book method
  def return_book(self):
   # set self.is_available to True
   self.is_available = True

# PROGRAM LOGIC

# create at least two book objects
book1 = Book("Python Basics", "Allen Downey")
book2 = Book("Lord of the Rings", "J.R.R. Tolkien")
# print both books
print("--- Library Status ---")
print(book1)
print(book2)
# checkout one book
print ("\nChecking out 'Lord of the Rings'...\n")
book2.checkout()

# print both books again
print("--- Updated Status ---")
print(book1)
print(book2)
# Out:
# --- Library Status ---
# Python Basics by Allen Downey - Available
# Lord of the Rings by J.R.R. Tolkien - Available
#
# Checking out 'Lord of the Rings'...
#
# --- Updated Status ---
# Python Basics by Allen Downey - Available
# Lord of the Rings by J.R.R. Tolkien - Checked Out
