# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/Chapter%205%20-%20Programming%20Exercise/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define calculate_ticket(age, hour)
# 2. Logic: If age <= 12 or age >= 65, price = 8. Otherwise, price = 12.
# 3. Logic: If hour < 17, subtract 2 from the price.
# 4. Print the final price.

# PROGRAM LOGIC
# 1. input() for age (int)
# 2. input() for movie hour (int)
# 3. Call calculate_ticket()
