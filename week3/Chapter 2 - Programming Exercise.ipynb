# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week3/Chapter%202%20-%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program logic
# Assign values to varibles: name, goal, birth_date, current_year
name = "Mohamed Shalaby"
goal = "Become a Cybersecurity expert"
birth_date = 2006
current_year = 2026
# Calculate Age
age = current_year - birth_date
# Print top border
print("=" * 25)
# Print bio sentance
print("My name is " + name + " and I am " + str(age) + " years old. My goal is to " + goal + ".")
# Print bottom border
print("=" * 25)
# Out:
# ...
# My name is Mohamed Shalaby and I am 20 years old. My goal is to Become a Cybersecurity expert.
# ...
