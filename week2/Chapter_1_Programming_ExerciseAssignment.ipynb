# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week2/Chapter_1_Programming_ExerciseAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# (None)

# PROGRAM LOGIG
# 1. Print the total of hours in a month (30 * 24)
print ("The total of hours in a month:" + str (30 * 24))

# 2. Print the year since world war II (2026 - 1945)
print ("The year since world war II:" + str (2026 - 1945))

# 3. Print the total cost of 21 shirts (21 * 8)
print ("The total cost of 21 shirts:" + str (21 * 8))
# Out:
# The total of hours in a month:720
# The year since world war II:81
# The total cost of 21 shirts:168
