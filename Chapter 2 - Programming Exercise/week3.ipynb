# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/Chapter%202%20-%20Programming%20Exercise/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program logic
# Assign values to varibles: name, goal, birth_date, current_year
# Calculate Age
# Print top border
# Print bio sentance
# Print bottom border
