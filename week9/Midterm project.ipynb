# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week9/Midterm%20project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# rentalcar.py

# FUNCTION DEFINITIONS
# get_class_name(code)
# get_daily_rate(code)
# calculate_total_miles(start, end)
# calculate_charged_miles(total_miles)
# calculate_total_bill(code, days, charged_miles)

# PROGRAM LOGIC
# get user input
# validate classification
# compute miles
# compute charged miles
# compute bill
# print summary
