# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week13/Chapter%2013%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: journal.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# write_entry function
# - accepts filename and entry
# - open file in append mode ('a')
# - write entry to file
# - add newline character so entries don't run together
# - close the file

# read_journal function
# - accepts filename
# - open file in read mode ('r')
# - read entire contents
# - print contents to screen
# - handle error if file does not exist

# PROGRAM LOGIC
# set filename (journal.txt)

# start while loop
#   ask user: Write, Read, or Quit

#   if user chooses Write:
#     ask for entry
#     call write_entry

#   if user chooses Read:
#     call read_journal

#   if user chooses Quit:
#     exit loop
