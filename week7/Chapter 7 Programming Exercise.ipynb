# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week7/Chapter%207%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
#    - Create a loop that asks for a PIN until it equals "1234"
#    - Return True
def verify_pin():
  while True:
    pin = input("Enter your PIN: ")
  if pin == "1234":
    print("PIN accepted.")
  else:
    print("Incorrect PIN. Try again.")
return True
# 2. Define withdraw(balance, amount):
def withdraw(balance, amount):
#    - Check if enough money exists
#    - Return the new (or old) balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
current_balance = 500
# 2. Call verify_pin()
vertify_pin(1234)
# 3. Get withdrawal amount from user input

# 4. Update current_balance by calling withdraw()

# 5. Print the final balance
# Out:
#   File "/tmp/ipython-input-1016733815.py", line 23
#     current_balance = 500
#     ^
# IndentationError: expected an indented block after function definition on line 17
