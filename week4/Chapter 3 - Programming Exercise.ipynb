# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week4/Chapter%203%20-%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio(name, age, goal):
    # 2. Inside the function, use string multiplication (*) for a border line.
    border = "*" * 25
    # 3. Print the bio details using the parameter names.
    print(border)
    print(f"Name: {name}", f"Age: {age}", f"Goal: {goal}")
    print(border)

# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio("Mohamed Shalaby", 19, "Master coding.")
# 2. Call print_bio using [Name of Famous Person].
print_bio("Tom Holland", 29, "Become a film director and winning the oscar.")
# 3. Call print_bio using [Name of Fictional Character].
print_bio("Spider-Man", 25, "Protect New York City")
# Out:
# *************************
# Name: Mohamed Shalaby Age: 19 Goal: Master coding.
# *************************
# *************************
# Name: Tom Holland Age: 29 Goal: Become a film director and winning the oscar.
# *************************
# *************************
# Name: Spider-Man Age: 25 Goal: Protect New York City
# *************************
