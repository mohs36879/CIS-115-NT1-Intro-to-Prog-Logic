# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week16/Final%20Project%20-%20Expense%20Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# expensetracker.py

# FUNCTION DEFINITIONS

# add_expense(expenses)
  # ask user for category
  # ask user for vendor
  # ask user for amount
    # try converting to float
    # if invalid, ask again
  # ask user for date
  # create dictionary with data
  # add dictionart to expenses list

# get_total_all(expenses)
  # set total to 0
  # loop through expenses
    # add each amount to total
  # return total

# get_total_category(expenses, category_input)
  # set total to 0
  # loop through expenses
    # if vendor matches input
      # add amount to total
  # return total

# PROGRAM LOGIC

# create empty expenses list

# start loop
  # display menu
  # get user choice

  # if choice is 11
    # call add_expense

  # if choice is 2
    # display total options
    # get option

    # if A
      # call get_total_all
      # print result

    # if C
      # ask for category
      # call get_total_category
      # print result

    # if V
      # ask for vendor
      # call get_total_vendor
      # print result

  # if choice is 3
    # exit loop
