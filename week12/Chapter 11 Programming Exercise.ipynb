# %% [markdown]
# <a href="https://colab.research.google.com/github/mohs36879/CIS-115-NT1-Intro-to-Prog-Logic/blob/main/week12/Chapter%2011%20Programming%20Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NAME: rectangle.py
# IMPORT STATEMENTS

# FUNCTION DEFINITIONS
# define a function called calculate_rectangle with length and width
# calculate area by multiplying length * width
# calculate perimeter using 2 * (length + width)
# return both values as a tuple (area, perimeter)

# PROGRAM LOGIC
# ask the user for length
# ask the user for width
# call the function
# unpack the returned tuple into my_area and my_perimeter
# print the results clearly
